# %%
library(OmnipathR)
library(nichenetr)
library(tidyverse)
library(mlrMBO)
library(parallelMap)
library(dplyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2      ✔ purrr   0.3.5
# ✔ tibble  3.2.1      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Warning message: 'mlr' is in 'maintenance-only' mode since July 2019.
# Future development will only happen in 'mlr3'
# (<https://mlr3.mlr-org.com>). Due to the focus on 'mlr3' there might be
# uncaught bugs meanwhile in {mlr} - please consider switching.
#
# Loading required package: smoof
#
# Loading required package: checkmate

# %%
interactionFormatTransf <- function(InputDf, InteractionType){
  
    OutputInt <- tibble(from = character(), to = character(), 
        source = character(), database = character())  
    
    n <- nrow(InputDf)
    sources <- dplyr::pull(InputDf, sources)
    sourceNodes <- dplyr::pull(InputDf, from)
    targetNodes <- dplyr::pull(InputDf, to)
    
    for (i in seq(n)){
        currentSources <- unlist(strsplit(sources[i],";"))
        for (j in seq(length(currentSources))){
            OutputInt <- add_row(OutputInt, 
                from = sourceNodes[i] , 
                to = targetNodes[i],  
                # source = paste(currentSources[j], InteractionType, sep="_"),
                source = currentSources[j],
                database = currentSources[j]) 
        }
    }
    
    return(OutputInt)
}

# %%
lr <- read.csv("../../run_CellPhoneDB/build_customDB/intersect_db.csv")

# %%
lr <- lr %>%
    select(protein_name_a,protein_name_b,sources) %>%
    rename(from=protein_name_a, to=protein_name_b) %>% 
    filter(from != to) %>% 
    distinct()

# %%
lr_Network_Omnipath <- 
    lr %>%
    interactionFormatTransf(InteractionType="LigrecExtra") %>%
    dplyr::distinct()

# %%
saveRDS(lr_Network_Omnipath, 
    "../../../../../results/method_comparison/build_customDB/NicheNet/lig_rec_sources.rds")

# %%
## We next get protein-protein interactions from the different datasets availabe
## in Omnipath
AllInteractions <- 
    import_post_translational_interactions(exclude = "ligrecextra") %>% 
    dplyr::select(source_genesymbol, target_genesymbol, sources) %>% 
    dplyr::rename(from=source_genesymbol, to=target_genesymbol) %>% 
    dplyr::filter(from != to) %>% 
    dplyr::distinct()

# %%
ligands <- unique(pull(lr, from))

# %%
# sig_Network_Omnipath <- sig_Network_Omnipath_raw

# %%
# ## Original Omnipath interactions
# sig_Network_Omnipath <- 
#     interactionFormatTransf(AllInteractions, InteractionType="Signalling") %>%
#     dplyr::distinct() 

# ## I have to remove self-interactions in the signaling network
# sig_Network_Omnipath <- sig_Network_Omnipath %>% 
#     dplyr::filter(from != to)

# # ## I also have to remove interactions going to ligands. See Methods Nichenet 
# # ## paper
# # sig_Network_Omnipath <- sig_Network_Omnipath %>% 
# #     dplyr::filter(!(to %in% ligands))

# ## There are in addition some records containing not input gene, we remove them
# ## since they are giving problems with running the model.
# sig_Network_Omnipath <- sig_Network_Omnipath %>% 
#     dplyr::filter(from != "") %>% 
#     dplyr::filter(to != "")


# ## We also remove signaling interactions that are already in the lig-receptor 
# ## network. 
# sig_Network_Omnipath <- dplyr::anti_join(
#   sig_Network_Omnipath, 
#   lr_Network_Omnipath, 
#   by = c("from" = "from", "to" = "to"))

# nrow(sig_Network_Omnipath)
# Out:
# [1] 204427

# %%
## Original Omnipath interactions
sig_Network_Omnipath <- 
    interactionFormatTransf(AllInteractions, InteractionType="Signalling") %>%
    dplyr::distinct() 

## I have to remove self-interactions in the signaling network
sig_Network_Omnipath <- sig_Network_Omnipath %>% 
    dplyr::filter(from != to)

# ## I also have to remove interactions going to ligands. See Methods Nichenet 
# ## paper
sig_Network_Omnipath <- sig_Network_Omnipath %>% 
    dplyr::filter(!(to %in% ligands))

## There are in addition some records containing not input gene, we remove them
## since they are giving problems with running the model.
sig_Network_Omnipath <- sig_Network_Omnipath %>% 
    dplyr::filter(from != "") %>% 
    dplyr::filter(to != "")


## We also remove signaling interactions that are already in the lig-receptor 
## network. 
sig_Network_Omnipath <- dplyr::anti_join(
  sig_Network_Omnipath, 
  lr_Network_Omnipath, 
  by = c("from" = "from", "to" = "to"))

nrow(sig_Network_Omnipath)
# Out:
# [1] 163533

# %%
202063

# %%
saveRDS(sig_Network_Omnipath, 
    "../../../../../results/method_comparison/build_customDB/NicheNet/sig_Network.rds")

# %%
gr_Interactions_Omnipath <- 
    import_dorothea_interactions(dorothea_levels = c("A","B","C")) %>%  
    select(source_genesymbol, target_genesymbol, sources) %>%
    rename(from=source_genesymbol, to=target_genesymbol) %>% 
    filter(from != to) %>%
    distinct()  

gr_Network_Omnipath <- 
    interactionFormatTransf(
        gr_Interactions_Omnipath, 
        InteractionType="Dorothea") %>%
    dplyr::distinct() 
nrow(gr_Network_Omnipath)
## [1] 113897
# Out:
# [1] 82767

# %%
saveRDS(gr_Network_Omnipath,
    "../../../../../results/method_comparison/build_customDB/NicheNet/gr_Network.rds")

# %%
expression_settings_validation <- 
    readRDS("../../../../../results/method_comparison/build_customDB/NicheNet/expression_settings.rds")

# index <- which(!unlist(lapply(expression_settings_validation, 
#     function(x) any(x$from != "IFNA1"))))

# expression_settings_validation <- expression_settings_validation[-index]

# %% [markdown]
# The process described above requires an internet connection to retrieve data. However, our compute nodes on the server do not have an internet connection. Therefore, it is necessary to run the initial steps locally, where we have access to the internet.
#
# Once these initial steps are completed, we can export the variables in a format that can be easily transferred to the server. For example, exporting the variables in .rds format ensures compatibility across different environments.
#
# After exporting the variables, they can be transferred to the server and loaded for further processing. Since the subsequent steps are compute-intensive, running them on the server's dedicated compute nodes can take advantage of their higher processing power and resources.
#
# In summary, the initial steps requiring an internet connection should be run locally, or on a server where internet access is available. The variables can then be exported and transferred to the server for subsequent compute-intensive steps. This approach allows us to leverage the server's resources while ensuring the availability of necessary data.

# %%
ls()
# Out:
#  [1] "AllInteractions"                "expression_settings_validation"
#  [3] "gr_Interactions_Omnipath"       "gr_Network_Omnipath"
#  [5] "index"                          "interactionFormatTransf"
#  [7] "ligands"                        "lr"
#  [9] "lr_Network_Omnipath"            "sig_Network_Omnipath"

# %%
save(list=c("expression_settings_validation", "lr_Network_Omnipath", "sig_Network_Omnipath", "gr_Network_Omnipath"), 
     file="myvariables.RData")

# %%
load("myvariables.RData")

# %%
All_sources <- unique(c(lr_Network_Omnipath$source,
    sig_Network_Omnipath$source, gr_Network_Omnipath$source))

my_source_weights_df <- 
     tibble(source = All_sources, weight = rep(1,length(All_sources)))

additional_arguments_topology_correction <- 
    list(source_names = my_source_weights_df$source %>% unique(), 
        algorithm = "PPR", 
        correct_topology = FALSE,
        lr_network = lr_Network_Omnipath, 
        sig_network = sig_Network_Omnipath, 
        gr_network = gr_Network_Omnipath, 
        settings = lapply(expression_settings_validation, 
            convert_expression_settings_evaluation), 
        secondary_targets = FALSE, 
        remove_direct_links = "no", 
        cutoff_method = "quantile")

nr_datasources <- additional_arguments_topology_correction$source_names %>% 
    length()

obj_fun_multi_topology_correction = makeMultiObjectiveFunction(name = "nichenet_optimization",
    description = "data source weight and hyperparameter optimization: expensive black-box function", 
    fn = model_evaluation_optimization, 
    par.set = makeParamSet(
        makeNumericVectorParam("source_weights", len = nr_datasources, 
            lower = 0, upper = 1, tunable = FALSE), 
        makeNumericVectorParam("lr_sig_hub", len = 1, lower = 0, upper = 1, 
            tunable = TRUE),  
        makeNumericVectorParam("gr_hub", len = 1, lower = 0, upper = 1, 
            tunable = TRUE),  
        makeNumericVectorParam("ltf_cutoff", len = 1, lower = 0.9, 
            upper = 0.999, tunable = TRUE),  
        makeNumericVectorParam("damping_factor", len = 1, lower = 0.01, 
            upper = 0.99, tunable =TRUE)), 
    has.simple.signature = FALSE,
    n.objectives = 4, 
    noisy = FALSE,
    minimize = c(FALSE,FALSE,FALSE,FALSE))

optimization_results = 
    lapply(1,mlrmbo_optimization, obj_fun = obj_fun_multi_topology_correction, 
           niter = 8, ncores = 8, nstart = 160, 
           additional_arguments = additional_arguments_topology_correction)

saveRDS(optimization_results, "../../../../../results/method_comparison/build_customDB/NicheNet/Optimization_results.rds")
# Out:
# Loading required package: mco
#
# Loading required package: emoa
#
#
# Attaching package: ‘emoa’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     coalesce
#
#
# Starting parallelization in mode=multicore with cpus=8.
#     source_weights1 source_weights2 source_weights3 source_weights4
# 1       0.573086530     0.197161192      0.84716006     0.673123345
# 2       0.835907162     0.733864774      0.79758742     0.885643229
# 3       0.538408570     0.809848102      0.29117820     0.068182781
# 4       0.881976855     0.934818693      0.28682059     0.698499324
# 5       0.957792874     0.466725397      0.21268005     0.910012755
# 6       0.106095174     0.278167165      0.10441599     0.597878822
# 7       0.426559470     0.022788042      0.77997195     0.122584433
# 8       0.607309964     0.821902719      0.26350140     0.976788360
# 9       0.535489195     0.764853560      0.87952276     0.927923836
# 10      0.948147720     0.804371007      0.48468673     0.205832290
# 11      0.308958887     0.685656322      0.44004282     0.251964406
# 12      0.734762657     0.252156479      0.38420661     0.556088028
# 13      0.924486880     0.267172686      0.14170283     0.438851193
# 14      0.460601223     0.563334274      0.67191988     0.959658634
# 15      0.677590115     0.140318295      0.78585768     0.318950538
# 16      0.703980260     0.483027152      0.08396642     0.826260257
# 17      0.166861425     0.779992855      0.54079809     0.416807828
# 24      0.1911111222      0.538894926     0.2372449508      0.854158862
# 25      0.0512928014      0.990107746     0.4642841308      0.173197359
# 26      0.5908134161      0.956354205     0.4082752794      0.884564784
# 27      0.6461891597      0.669840742     0.9776079008      0.526338233
# 28      0.3845759318      0.930803140     0.8702699668      0.509117948
# 29      0.0088632203      0.007974425     0.1074273269      0.121042798
# 30      0.4931643672      0.506758024     0.2456423873      0.385853988
# 31      0.7315015929      0.275295182     0.5334123549      0.982481068
# 32      0.3949125337      0.998486667     0.5399202547      0.818888644
# 33      0.3269741360      0.272542810     0.9195462573      0.733850849
# 34      0.5218018001      0.528225521     0.6814985635      0.141485602
# 35      0.0476689096      0.784777254     0.6255905232      0.519686790
# 36      0.9348016776      0.190944657     0.1188059899      0.998398071
# 37      0.8398106199      0.247035466     0.2262596214      0.392557125
# 38      0.3697045721      0.327908877     0.1525102881      0.166661918
# ...
#
# [mbo] 0: source_weights=0.377,0.829,...; lr_sig_hub=0.0204; gr_hub=0.997; ltf_cutoff=0.973; damping_factor=0.746 : y_1 = 0.6, y_2 = 0.0141, y_3 = 0.71, y_4 = 0.0195 : 348.4 secs : initdesign
#
# [mbo] 0: source_weights=0.265,0.364,...; lr_sig_hub=0.925; gr_hub=0.18; ltf_cutoff=0.996; damping_factor=0.454 : y_1 = 0.542, y_2 = 0.026, y_3 = 0.66, y_4 = 0.0098 : 529.0 secs : initdesign
#
# [mbo] 0: source_weights=0.0576,0.236...; lr_sig_hub=0.321; gr_hub=0.147; ltf_cutoff=0.947; damping_factor=0.533 : y_1 = 0.607, y_2 = 0.0291, y_3 = 0.74, y_4 = 0.0307 : 548.5 secs : initdesign
#
# [mbo] 0: source_weights=0.862,0.526,...; lr_sig_hub=0.179; gr_hub=0.977; ltf_cutoff=0.941; damping_factor=0.93 : y_1 = 0.607, y_2 = 0.0177, y_3 = 0.7, y_4 = 0.0161 : 641.0 secs : initdesign
#
# [mbo] 0: source_weights=0.177,0.413,...; lr_sig_hub=0.34; gr_hub=0.0422; ltf_cutoff=0.969; damping_factor=0.127 : y_1 = 0.596, y_2 = 0.0272, y_3 = 0.78, y_4 = 0.0394 : 638.6 secs : initdesign
#
# [mbo] 0: source_weights=0.11,0.558,0...; lr_sig_hub=0.0702; gr_hub=0.189; ltf_cutoff=0.988; damping_factor=0.189 : y_1 = 0.588, y_2 = 0.0266, y_3 = 0.762, y_4 = 0.0325 : 467.7 secs : initdesign
#
# [mbo] 0: source_weights=0.891,0.929,...; lr_sig_hub=6.23e-05; gr_hub=0.381; ltf_cutoff=0.981; damping_factor=0.954 : y_1 = 0.608, y_2 = 0.0254, y_3 = 0.76, y_4 = 0.0274 : 560.3 secs : initdesign
#
# [mbo] 0: source_weights=0.621,0.33,0...; lr_sig_hub=0.528; gr_hub=0.702; ltf_cutoff=0.934; damping_factor=0.555 : y_1 = 0.603, y_2 = 0.0255, y_3 = 0.74, y_4 = 0.0221 : 490.0 secs : initdesign
#
# [mbo] 0: source_weights=0.994,0.273,...; lr_sig_hub=0.871; gr_hub=0.557; ltf_cutoff=0.943; damping_factor=0.616 : y_1 = 0.599, y_2 = 0.0279, y_3 = 0.755, y_4 = 0.0189 : 346.8 secs : initdesign
#
# [mbo] 0: source_weights=0.87,0.912,0...; lr_sig_hub=0.429; gr_hub=0.293; ltf_cutoff=0.957; damping_factor=0.587 : y_1 = 0.601, y_2 = 0.0286, y_3 = 0.746, y_4 = 0.0402 : 481.1 secs : initdesign
#
# [mbo] 0: source_weights=0.768,0.0481...; lr_sig_hub=0.806; gr_hub=0.826; ltf_cutoff=0.997; damping_factor=0.488 : y_1 = 0.536, y_2 = 0.0224, y_3 = 0.62, y_4 = 0.00565 : 563.1 secs : initdesign
#
# [mbo] 0: source_weights=0.0409,0.891...; lr_sig_hub=0.0286; gr_hub=0.251; ltf_cutoff=0.923; damping_factor=0.288 : y_1 = 0.607, y_2 = 0.0253, y_3 = 0.76, y_4 = 0.0359 : 509.3 secs : initdesign
#
# [mbo] 0: source_weights=0.851,0.656,...; lr_sig_hub=0.217; gr_hub=0.511; ltf_cutoff=0.963; damping_factor=0.983 : y_1 = 0.605, y_2 = 0.0192, y_3 = 0.704, y_4 = 0.0179 : 592.9 secs : initdesign
#
# [mbo] 0: source_weights=0.39,0.392,0...; lr_sig_hub=0.207; gr_hub=0.64; ltf_cutoff=0.977; damping_factor=0.717 : y_1 = 0.603, y_2 = 0.0235, y_3 = 0.68, y_4 = 0.0156 : 464.5 secs : initdesign
#
# [mbo] 0: source_weights=0.191,0.445,...; lr_sig_hub=0.332; gr_hub=0.514; ltf_cutoff=0.925; damping_factor=0.787 : y_1 = 0.606, y_2 = 0.023, y_3 = 0.7, y_4 = 0.0161 : 586.3 secs : initdesign
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 1: source_weights=0.668,0.702,...; lr_sig_hub=0.587; gr_hub=0.432; ltf_cutoff=0.955; damping_factor=0.829 : y_1 = 0.606, y_2 = 0.0322, y_3 = 0.78, y_4 = 0.0359 : 543.0 secs : infill_dib
#
# [mbo] 1: source_weights=0.74,0.0972,...; lr_sig_hub=0.551; gr_hub=0.49; ltf_cutoff=0.928; damping_factor=0.15 : y_1 = 0.603, y_2 = 0.0264, y_3 = 0.78, y_4 = 0.0304 : 599.9 secs : infill_dib
#
# [mbo] 1: source_weights=0.905,0.733,...; lr_sig_hub=0.946; gr_hub=0.115; ltf_cutoff=0.911; damping_factor=0.393 : y_1 = 0.602, y_2 = 0.0278, y_3 = 0.72, y_4 = 0.028 : 589.2 secs : infill_dib
#
# [mbo] 1: source_weights=0.989,0.228,...; lr_sig_hub=0.328; gr_hub=0.155; ltf_cutoff=0.946; damping_factor=0.372 : y_1 = 0.605, y_2 = 0.0275, y_3 = 0.76, y_4 = 0.0359 : 643.4 secs : infill_dib
#
# [mbo] 1: source_weights=0.718,0.412,...; lr_sig_hub=0.539; gr_hub=0.407; ltf_cutoff=0.937; damping_factor=0.056 : y_1 = 0.598, y_2 = 0.0207, y_3 = 0.72, y_4 = 0.0284 : 561.1 secs : infill_dib
#
# [mbo] 1: source_weights=0.51,0.717,0...; lr_sig_hub=0.467; gr_hub=0.0362; ltf_cutoff=0.984; damping_factor=0.25 : y_1 = 0.584, y_2 = 0.0309, y_3 = 0.74, y_4 = 0.0359 : 465.0 secs : infill_dib
#
# [mbo] 1: source_weights=0.577,0.572,...; lr_sig_hub=0.353; gr_hub=0.042; ltf_cutoff=0.972; damping_factor=0.524 : y_1 = 0.6, y_2 = 0.0309, y_3 = 0.786, y_4 = 0.0359 : 512.5 secs : infill_dib
#
# [mbo] 1: source_weights=0.13,0.713,0...; lr_sig_hub=0.772; gr_hub=0.791; ltf_cutoff=0.959; damping_factor=0.316 : y_1 = 0.592, y_2 = 0.0216, y_3 = 0.74, y_4 = 0.029 : 821.5 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 2: source_weights=0.752,0.421,...; lr_sig_hub=0.387; gr_hub=0.239; ltf_cutoff=0.926; damping_factor=0.586 : y_1 = 0.606, y_2 = 0.0309, y_3 = 0.77, y_4 = 0.0429 : 570.2 secs : infill_dib
#
# [mbo] 2: source_weights=0.45,0.255,0...; lr_sig_hub=0.237; gr_hub=0.0575; ltf_cutoff=0.969; damping_factor=0.771 : y_1 = 0.609, y_2 = 0.0305, y_3 = 0.74, y_4 = 0.0304 : 502.2 secs : infill_dib
# [mbo] 2: source_weights=0.6,0.552,0....; lr_sig_hub=0.882; gr_hub=0.276; ltf_cutoff=0.962; damping_factor=0.686 : y_1 = 0.599, y_2 = 0.0314, y_3 = 0.78, y_4 = 0.0304 : 622.3 secs : infill_dib
#
# [mbo] 2: source_weights=0.16,0.0743,...; lr_sig_hub=0.091; gr_hub=0.581; ltf_cutoff=0.956; damping_factor=0.347 : y_1 = 0.602, y_2 = 0.0236, y_3 = 0.78, y_4 = 0.0304 : 545.8 secs : infill_dib
#
# [mbo] 2: source_weights=0.0667,0.698...; lr_sig_hub=0.39; gr_hub=0.25; ltf_cutoff=0.956; damping_factor=0.692 : y_1 = 0.61, y_2 = 0.0312, y_3 = 0.72, y_4 = 0.0246 : 507.4 secs : infill_dib
#
# [mbo] 2: source_weights=0.503,0.354,...; lr_sig_hub=0.518; gr_hub=0.178; ltf_cutoff=0.911; damping_factor=0.801 : y_1 = 0.608, y_2 = 0.0285, y_3 = 0.8, y_4 = 0.0429 : 757.9 secs : infill_dib
#
# [mbo] 2: source_weights=0.649,0.72,0...; lr_sig_hub=0.126; gr_hub=0.772; ltf_cutoff=0.94; damping_factor=0.631 : y_1 = 0.6, y_2 = 0.0161, y_3 = 0.73, y_4 = 0.0189 : 663.2 secs : infill_dib
#
# [mbo] 2: source_weights=0.82,0.161,0...; lr_sig_hub=0.0929; gr_hub=0.226; ltf_cutoff=0.935; damping_factor=0.757 : y_1 = 0.607, y_2 = 0.0266, y_3 = 0.745, y_4 = 0.0361 : 731.6 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 3: source_weights=0.606,0.229,...; lr_sig_hub=0.616; gr_hub=0.54; ltf_cutoff=0.953; damping_factor=0.567 : y_1 = 0.601, y_2 = 0.0286, y_3 = 0.77, y_4 = 0.0304 : 486.2 secs : infill_dib
#
# [mbo] 3: source_weights=0.385,0.224,...; lr_sig_hub=0.7; gr_hub=0.271; ltf_cutoff=0.971; damping_factor=0.613 : y_1 = 0.594, y_2 = 0.0302, y_3 = 0.78, y_4 = 0.0344 : 523.6 secs : infill_dib
#
# [mbo] 3: source_weights=0.468,0.835,...; lr_sig_hub=0.779; gr_hub=0.118; ltf_cutoff=0.979; damping_factor=0.116 : y_1 = 0.581, y_2 = 0.0263, y_3 = 0.716, y_4 = 0.0304 : 603.6 secs : infill_dib
#
# [mbo] 3: source_weights=0.385,0.367,...; lr_sig_hub=0.39; gr_hub=0.826; ltf_cutoff=0.957; damping_factor=0.417 : y_1 = 0.595, y_2 = 0.0152, y_3 = 0.724, y_4 = 0.0221 : 489.4 secs : infill_dib
#
# [mbo] 3: source_weights=0.614,0.51,0...; lr_sig_hub=0.614; gr_hub=0.456; ltf_cutoff=0.968; damping_factor=0.874 : y_1 = 0.601, y_2 = 0.0278, y_3 = 0.68, y_4 = 0.0198 : 489.8 secs : infill_dib
#
# [mbo] 3: source_weights=0.202,0.494,...; lr_sig_hub=0.822; gr_hub=0.623; ltf_cutoff=0.921; damping_factor=0.307 : y_1 = 0.6, y_2 = 0.0235, y_3 = 0.74, y_4 = 0.0258 : 663.9 secs : infill_dib
#
# [mbo] 3: source_weights=0.508,0.339,...; lr_sig_hub=0.82; gr_hub=0.872; ltf_cutoff=0.959; damping_factor=0.142 : y_1 = 0.593, y_2 = 0.0213, y_3 = 0.67, y_4 = 0.018 : 533.1 secs : infill_dib
#
# [mbo] 3: source_weights=0.236,0.266,...; lr_sig_hub=0.603; gr_hub=0.299; ltf_cutoff=0.925; damping_factor=0.935 : y_1 = 0.612, y_2 = 0.0322, y_3 = 0.747, y_4 = 0.0237 : 853.9 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 4: source_weights=0.886,0.182,...; lr_sig_hub=0.887; gr_hub=0.802; ltf_cutoff=0.914; damping_factor=0.671 : y_1 = 0.6, y_2 = 0.0214, y_3 = 0.7, y_4 = 0.0161 : 516.7 secs : infill_dib
#
# [mbo] 4: source_weights=0.17,0.356,0...; lr_sig_hub=0.361; gr_hub=0.334; ltf_cutoff=0.961; damping_factor=0.743 : y_1 = 0.606, y_2 = 0.0301, y_3 = 0.76, y_4 = 0.0346 : 611.0 secs : infill_dib
#
# [mbo] 4: source_weights=0.258,0.407,...; lr_sig_hub=0.6; gr_hub=0.149; ltf_cutoff=0.966; damping_factor=0.774 : y_1 = 0.601, y_2 = 0.0323, y_3 = 0.81, y_4 = 0.0429 : 490.8 secs : infill_dib
#
# [mbo] 4: source_weights=0.623,0.879,...; lr_sig_hub=0.154; gr_hub=0.552; ltf_cutoff=0.955; damping_factor=0.714 : y_1 = 0.609, y_2 = 0.0265, y_3 = 0.717, y_4 = 0.0269 : 646.4 secs : infill_dib
#
# [mbo] 4: source_weights=0.341,0.743,...; lr_sig_hub=0.786; gr_hub=0.164; ltf_cutoff=0.961; damping_factor=0.761 : y_1 = 0.599, y_2 = 0.0339, y_3 = 0.79, y_4 = 0.026 : 540.5 secs : infill_dib
#
# [mbo] 4: source_weights=0.625,0.531,...; lr_sig_hub=0.0751; gr_hub=0.432; ltf_cutoff=0.901; damping_factor=0.575 : y_1 = 0.606, y_2 = 0.0222, y_3 = 0.745, y_4 = 0.0288 : 719.0 secs : infill_dib
#
# [mbo] 4: source_weights=0.302,0.668,...; lr_sig_hub=0.33; gr_hub=0.809; ltf_cutoff=0.921; damping_factor=0.736 : y_1 = 0.608, y_2 = 0.0222, y_3 = 0.75, y_4 = 0.0229 : 790.1 secs : infill_dib
#
# [mbo] 4: source_weights=0.708,0.918,...; lr_sig_hub=0.375; gr_hub=0.503; ltf_cutoff=0.978; damping_factor=0.321 : y_1 = 0.591, y_2 = 0.0223, y_3 = 0.71, y_4 = 0.0221 : 527.0 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 5: source_weights=0.736,0.259,...; lr_sig_hub=0.597; gr_hub=0.869; ltf_cutoff=0.938; damping_factor=0.464 : y_1 = 0.602, y_2 = 0.0191, y_3 = 0.68, y_4 = 0.0161 : 595.9 secs : infill_dib
#
# [mbo] 5: source_weights=0.408,0.134,...; lr_sig_hub=0.308; gr_hub=0.896; ltf_cutoff=0.97; damping_factor=0.0239 : y_1 = 0.593, y_2 = 0.0171, y_3 = 0.701, y_4 = 0.0232 : 823.9 secs : infill_dib
#
# [mbo] 5: source_weights=0.927,0.146,...; lr_sig_hub=0.224; gr_hub=0.114; ltf_cutoff=0.978; damping_factor=0.49 : y_1 = 0.599, y_2 = 0.0281, y_3 = 0.74, y_4 = 0.0405 : 516.1 secs : infill_dib
#
# [mbo] 5: source_weights=0.288,0.159,...; lr_sig_hub=0.39; gr_hub=0.426; ltf_cutoff=0.961; damping_factor=0.24 : y_1 = 0.597, y_2 = 0.0231, y_3 = 0.72, y_4 = 0.0274 : 556.8 secs : infill_dib
#
# [mbo] 5: source_weights=0.765,0.5,0....; lr_sig_hub=0.288; gr_hub=0.878; ltf_cutoff=0.929; damping_factor=0.382 : y_1 = 0.599, y_2 = 0.0166, y_3 = 0.75, y_4 = 0.0304 : 627.2 secs : infill_dib
#
# [mbo] 5: source_weights=0.372,0.765,...; lr_sig_hub=0.162; gr_hub=0.339; ltf_cutoff=0.975; damping_factor=0.988 : y_1 = 0.607, y_2 = 0.0226, y_3 = 0.79, y_4 = 0.0332 : 552.7 secs : infill_dib
#
# [mbo] 5: source_weights=0.582,0.56,0...; lr_sig_hub=0.555; gr_hub=0.973; ltf_cutoff=0.952; damping_factor=0.719 : y_1 = 0.596, y_2 = 0.0168, y_3 = 0.58, y_4 = 0.00817 : 608.8 secs : infill_dib
#
# [mbo] 5: source_weights=0.654,0.791,...; lr_sig_hub=0.734; gr_hub=0.225; ltf_cutoff=0.949; damping_factor=0.234 : y_1 = 0.597, y_2 = 0.0287, y_3 = 0.79, y_4 = 0.0331 : 522.2 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 6: source_weights=0.0474,0.765...; lr_sig_hub=0.659; gr_hub=0.702; ltf_cutoff=0.933; damping_factor=0.146 : y_1 = 0.598, y_2 = 0.0211, y_3 = 0.71, y_4 = 0.0258 : 562.1 secs : infill_dib
#
# [mbo] 6: source_weights=0.587,0.224,...; lr_sig_hub=0.611; gr_hub=0.655; ltf_cutoff=0.908; damping_factor=0.572 : y_1 = 0.612, y_2 = 0.027, y_3 = 0.76, y_4 = 0.0238 : 871.9 secs : infill_dib
#
# [mbo] 6: source_weights=0.443,0.59,0...; lr_sig_hub=0.769; gr_hub=0.826; ltf_cutoff=0.933; damping_factor=0.209 : y_1 = 0.596, y_2 = 0.0186, y_3 = 0.7, y_4 = 0.0232 : 505.4 secs : infill_dib
#
# [mbo] 6: source_weights=0.115,0.491,...; lr_sig_hub=0.0885; gr_hub=0.0755; ltf_cutoff=0.968; damping_factor=0.4 : y_1 = 0.606, y_2 = 0.0295, y_3 = 0.78, y_4 = 0.0429 : 511.9 secs : infill_dib
#
# [mbo] 6: source_weights=0.22,0.586,0...; lr_sig_hub=0.33; gr_hub=0.692; ltf_cutoff=0.97; damping_factor=0.942 : y_1 = 0.603, y_2 = 0.0178, y_3 = 0.7, y_4 = 0.0171 : 560.5 secs : infill_dib
#
# [mbo] 6: source_weights=0.423,0.268,...; lr_sig_hub=0.253; gr_hub=0.848; ltf_cutoff=0.922; damping_factor=0.299 : y_1 = 0.597, y_2 = 0.0151, y_3 = 0.72, y_4 = 0.0258 : 586.5 secs : infill_dib
#
# [mbo] 6: source_weights=0.687,0.136,...; lr_sig_hub=0.319; gr_hub=0.529; ltf_cutoff=0.981; damping_factor=0.872 : y_1 = 0.601, y_2 = 0.0306, y_3 = 0.746, y_4 = 0.0258 : 595.8 secs : infill_dib
#
# [mbo] 6: source_weights=0.902,0.566,...; lr_sig_hub=0.868; gr_hub=0.237; ltf_cutoff=0.942; damping_factor=0.334 : y_1 = 0.6, y_2 = 0.0275, y_3 = 0.73, y_4 = 0.0258 : 623.4 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 7: source_weights=0.561,0.504,...; lr_sig_hub=0.682; gr_hub=0.369; ltf_cutoff=0.978; damping_factor=0.288 : y_1 = 0.582, y_2 = 0.029, y_3 = 0.68, y_4 = 0.0098 : 569.1 secs : infill_dib
#
# [mbo] 7: source_weights=0.143,0.582,...; lr_sig_hub=0.583; gr_hub=0.01; ltf_cutoff=0.917; damping_factor=0.658 : y_1 = 0.607, y_2 = 0.0273, y_3 = 0.78, y_4 = 0.029 : 535.7 secs : infill_dib
#
# [mbo] 7: source_weights=0.0677,0.737...; lr_sig_hub=0.687; gr_hub=0.396; ltf_cutoff=0.943; damping_factor=0.848 : y_1 = 0.608, y_2 = 0.0315, y_3 = 0.74, y_4 = 0.0189 : 583.9 secs : infill_dib
# [mbo] 7: source_weights=0.939,0.706,...; lr_sig_hub=0.845; gr_hub=0.101; ltf_cutoff=0.924; damping_factor=0.96 : y_1 = 0.609, y_2 = 0.031, y_3 = 0.82, y_4 = 0.0359 : 524.6 secs : infill_dib
#
# [mbo] 7: source_weights=0.85,0.641,0...; lr_sig_hub=0.1; gr_hub=0.778; ltf_cutoff=0.988; damping_factor=0.316 : y_1 = 0.585, y_2 = 0.0217, y_3 = 0.737, y_4 = 0.0258 : 518.6 secs : infill_dib
#
# [mbo] 7: source_weights=0.547,0.561,...; lr_sig_hub=0.215; gr_hub=0.875; ltf_cutoff=0.968; damping_factor=0.736 : y_1 = 0.602, y_2 = 0.0188, y_3 = 0.72, y_4 = 0.0161 : 586.5 secs : infill_dib
#
# [mbo] 7: source_weights=0.546,0.252,...; lr_sig_hub=0.453; gr_hub=0.448; ltf_cutoff=0.929; damping_factor=0.861 : y_1 = 0.614, y_2 = 0.0329, y_3 = 0.684, y_4 = 0.0221 : 660.9 secs : infill_dib
#
# [mbo] 7: source_weights=0.238,0.421,...; lr_sig_hub=0.928; gr_hub=0.881; ltf_cutoff=0.94; damping_factor=0.338 : y_1 = 0.59, y_2 = 0.0199, y_3 = 0.7, y_4 = 0.0179 : 825.3 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 8: source_weights=0.467,0.939,...; lr_sig_hub=0.327; gr_hub=0.774; ltf_cutoff=0.939; damping_factor=0.422 : y_1 = 0.603, y_2 = 0.0192, y_3 = 0.72, y_4 = 0.0262 : 677.4 secs : infill_dib
#
# [mbo] 8: source_weights=0.0997,0.408...; lr_sig_hub=0.461; gr_hub=0.522; ltf_cutoff=0.921; damping_factor=0.54 : y_1 = 0.608, y_2 = 0.0286, y_3 = 0.751, y_4 = 0.0286 : 547.0 secs : infill_dib
#
# [mbo] 8: source_weights=0.975,0.867,...; lr_sig_hub=0.499; gr_hub=0.695; ltf_cutoff=0.956; damping_factor=0.724 : y_1 = 0.601, y_2 = 0.0238, y_3 = 0.75, y_4 = 0.0258 : 609.3 secs : infill_dib
#
# [mbo] 8: source_weights=0.512,0.355,...; lr_sig_hub=0.0158; gr_hub=0.217; ltf_cutoff=0.952; damping_factor=0.631 : y_1 = 0.606, y_2 = 0.0271, y_3 = 0.78, y_4 = 0.0359 : 822.9 secs : infill_dib
#
# [mbo] 8: source_weights=0.227,0.179,...; lr_sig_hub=0.248; gr_hub=0.997; ltf_cutoff=0.931; damping_factor=0.0962 : y_1 = 0.6, y_2 = 0.0159, y_3 = 0.716, y_4 = 0.0221 : 560.6 secs : infill_dib
#
# [mbo] 8: source_weights=0.112,0.713,...; lr_sig_hub=0.655; gr_hub=0.324; ltf_cutoff=0.902; damping_factor=0.531 : y_1 = 0.604, y_2 = 0.0304, y_3 = 0.77, y_4 = 0.0359 : 603.8 secs : infill_dib
#
# [mbo] 8: source_weights=0.878,0.514,...; lr_sig_hub=0.606; gr_hub=0.774; ltf_cutoff=0.921; damping_factor=0.253 : y_1 = 0.599, y_2 = 0.0195, y_3 = 0.74, y_4 = 0.0304 : 540.7 secs : infill_dib
#
# [mbo] 8: source_weights=0.651,0.926,...; lr_sig_hub=0.49; gr_hub=0.939; ltf_cutoff=0.991; damping_factor=0.501 : y_1 = 0.575, y_2 = 0.0244, y_3 = 0.72, y_4 = 0.023 : 522.4 secs : infill_dib
#
# Stopped parallelization. All cleaned up.
