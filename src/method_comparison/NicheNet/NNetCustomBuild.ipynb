# %%
library(OmnipathR)
library(nichenetr)
library(tidyverse)
library(mlrMBO)
library(parallelMap)
library(dplyr)
# Out:
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Warning message: 'mlr' is in 'maintenance-only' mode since July 2019.
# Future development will only happen in 'mlr3'
# (<https://mlr3.mlr-org.com>). Due to the focus on 'mlr3' there might be
# uncaught bugs meanwhile in {mlr} - please consider switching.
#
# Loading required package: smoof
#
# Loading required package: checkmate

# %%
interactionFormatTransf <- function(InputDf, InteractionType){
  
    OutputInt <- tibble(from = character(), to = character(), 
        source = character(), database = character())  
    
    n <- nrow(InputDf)
    sources <- dplyr::pull(InputDf, sources)
    sourceNodes <- dplyr::pull(InputDf, from)
    targetNodes <- dplyr::pull(InputDf, to)
    
    for (i in seq(n)){
        currentSources <- unlist(strsplit(sources[i],";"))
        for (j in seq(length(currentSources))){
            OutputInt <- add_row(OutputInt, 
                from = sourceNodes[i] , 
                to = targetNodes[i],  
                # source = paste(currentSources[j], InteractionType, sep="_"),
                source = currentSources[j],
                database = currentSources[j]) 
        }
    }
    
    return(OutputInt)
}

# %%
lr <- read.csv("../CPDB/intersect_db.csv")

# %%
lr <- lr %>%
    select(protein_name_a,protein_name_b,sources) %>%
    rename(from=protein_name_a, to=protein_name_b) %>% 
    filter(from != to) %>% 
    distinct()

# %%
lr_Network_Omnipath <- 
    lr %>%
    interactionFormatTransf(InteractionType="LigrecExtra") %>%
    dplyr::distinct()

# %%
saveRDS(lr_Network_Omnipath, 
    "NNET_Custom/lig_rec_sources.rds")

# %%
## We next get protein-protein interactions from the different datasets availabe
## in Omnipath
AllInteractions <- 
    import_post_translational_interactions(exclude = "ligrecextra") %>% 
    dplyr::select(source_genesymbol, target_genesymbol, sources) %>% 
    dplyr::rename(from=source_genesymbol, to=target_genesymbol) %>% 
    dplyr::filter(from != to) %>% 
    dplyr::distinct()

# %%
ligands <- unique(pull(lr, from))

# %%
# sig_Network_Omnipath <- sig_Network_Omnipath_raw

# %%
## Original Omnipath interactions
sig_Network_Omnipath <- 
    interactionFormatTransf(AllInteractions, InteractionType="Signalling") %>%
    dplyr::distinct() 

## I have to remove self-interactions in the signaling network
sig_Network_Omnipath <- sig_Network_Omnipath %>% 
    dplyr::filter(from != to)

# ## I also have to remove interactions going to ligands. See Methods Nichenet 
# ## paper
# sig_Network_Omnipath <- sig_Network_Omnipath %>% 
#     dplyr::filter(!(to %in% ligands))

## There are in addition some records containing not input gene, we remove them
## since they are giving problems with running the model.
sig_Network_Omnipath <- sig_Network_Omnipath %>% 
    dplyr::filter(from != "") %>% 
    dplyr::filter(to != "")


## We also remove signaling interactions that are already in the lig-receptor 
## network. 
sig_Network_Omnipath <- dplyr::anti_join(
  sig_Network_Omnipath, 
  lr_Network_Omnipath, 
  by = c("from" = "from", "to" = "to"))

nrow(sig_Network_Omnipath)
# Out:
# [1] 204326

# %%
saveRDS(sig_Network_Omnipath, 
    "NNET_Custom/sig_Network.rds")

# %%
gr_Interactions_Omnipath <- 
    import_dorothea_interactions(dorothea_levels = c("A","B","C")) %>%  
    select(source_genesymbol, target_genesymbol, sources) %>%
    rename(from=source_genesymbol, to=target_genesymbol) %>% 
    filter(from != to) %>%
    distinct()  

gr_Network_Omnipath <- 
    interactionFormatTransf(
        gr_Interactions_Omnipath, 
        InteractionType="Dorothea") %>%
    dplyr::distinct() 
nrow(gr_Network_Omnipath)
## [1] 113897
# Out:
# [1] 82767

# %%
saveRDS(gr_Network_Omnipath,
    "NNET_Custom/gr_Network.rds")

# %%
expression_settings_validation <- 
    readRDS("expression_settings.rds")

# index <- which(!unlist(lapply(expression_settings_validation, 
#     function(x) any(x$from != "IFNA1"))))

# expression_settings_validation <- expression_settings_validation[-index]

# %%
All_sources <- unique(c(lr_Network_Omnipath$source,
    sig_Network_Omnipath$source, gr_Network_Omnipath$source))

my_source_weights_df <- 
     tibble(source = All_sources, weight = rep(1,length(All_sources)))

additional_arguments_topology_correction <- 
    list(source_names = my_source_weights_df$source %>% unique(), 
        algorithm = "PPR", 
        correct_topology = FALSE,
        lr_network = lr_Network_Omnipath, 
        sig_network = sig_Network_Omnipath, 
        gr_network = gr_Network_Omnipath, 
        settings = lapply(expression_settings_validation, 
            convert_expression_settings_evaluation), 
        secondary_targets = FALSE, 
        remove_direct_links = "no", 
        cutoff_method = "quantile")

nr_datasources <- additional_arguments_topology_correction$source_names %>% 
    length()

obj_fun_multi_topology_correction = makeMultiObjectiveFunction(name = "nichenet_optimization",
    description = "data source weight and hyperparameter optimization: expensive black-box function", 
    fn = model_evaluation_optimization, 
    par.set = makeParamSet(
        makeNumericVectorParam("source_weights", len = nr_datasources, 
            lower = 0, upper = 1, tunable = FALSE), 
        makeNumericVectorParam("lr_sig_hub", len = 1, lower = 0, upper = 1, 
            tunable = TRUE),  
        makeNumericVectorParam("gr_hub", len = 1, lower = 0, upper = 1, 
            tunable = TRUE),  
        makeNumericVectorParam("ltf_cutoff", len = 1, lower = 0.9, 
            upper = 0.999, tunable = TRUE),  
        makeNumericVectorParam("damping_factor", len = 1, lower = 0.01, 
            upper = 0.99, tunable =TRUE)), 
    has.simple.signature = FALSE,
    n.objectives = 4, 
    noisy = FALSE,
    minimize = c(FALSE,FALSE,FALSE,FALSE))

optimization_results = 
    lapply(1,mlrmbo_optimization, obj_fun = obj_fun_multi_topology_correction, 
           niter = 8, ncores = 8, nstart = 160, 
           additional_arguments = additional_arguments_topology_correction)

saveRDS(optimization_results, "NNET_Custom/Optimization_results.rds")
# Out:
# Loading required package: mco
#
# Loading required package: emoa
#
#
# Attaching package: ‘emoa’
#
#
# The following object is masked from ‘package:dplyr’:
#
#
# 18       0.006234443      0.754435651      0.478819141      0.873396081
# 19       0.897948502      0.833752099      0.623769859      0.868210946
# 20       0.765300226      0.197841246      0.586501985      0.029137839
# 21       0.076547863      0.618025080      0.217670158      0.895101979
# 22       0.992175331      0.134680680      0.918442016      0.023015044
# 23       0.651357688      0.445386641      0.690068399      0.622223682
# 24       0.630047671      0.396012209      0.002953413      0.562848298
# 25       0.816964698      0.190561928      0.453246073      0.047474086
# 26       0.133332764      0.119716510      0.806282262      0.693002151
# 27       0.411565137      0.952998198      0.714610965      0.073098495
# 28       0.546993332      0.903604187      0.910967838      0.921049697
# 29       0.154543212      0.553064350      0.563531667      0.931214827
# 30       0.739890859      0.419108469      0.116138616      0.853229916
# 31       0.009365237      0.073671815      0.970887701      0.572624899
# 32       0.295286126      0.244476376      0.814406765      0.298409010
# 33       0.572612419      0.112797694      0.299323349      0.038209250
# 34       0.805200268      0.019860129      0.866570073      0.739752029
# 35       0.091573927      0.571254258      0.990822168      0.933847116
# 36       0.199905867      0.576384953      0.420509470      0.903932937
# 37       0.657233312      0.515464209      0.139677400      0.163703039
# 38       0.866443616      0.296606993      0.049935914      0.509231584
# ...
#
# [mbo] 0: source_weights=0.917,0.794,...; lr_sig_hub=0.273; gr_hub=0.057; ltf_cutoff=0.997; damping_factor=0.808 : y_1 = 0.563, y_2 = 0.0345, y_3 = 0.735, y_4 = 0.0231 : 516.9 secs : initdesign
#
# [mbo] 0: source_weights=0.956,0.399,...; lr_sig_hub=0.311; gr_hub=0.496; ltf_cutoff=0.981; damping_factor=0.133 : y_1 = 0.587, y_2 = 0.0249, y_3 = 0.74, y_4 = 0.0359 : 531.5 secs : initdesign
#
# [mbo] 0: source_weights=0.329,0.149,...; lr_sig_hub=0.672; gr_hub=0.778; ltf_cutoff=0.995; damping_factor=0.454 : y_1 = 0.556, y_2 = 0.0259, y_3 = 0.73, y_4 = 0.0193 : 338.2 secs : initdesign
#
# [mbo] 0: source_weights=0.493,0.712,...; lr_sig_hub=0.969; gr_hub=0.861; ltf_cutoff=0.982; damping_factor=0.674 : y_1 = 0.575, y_2 = 0.0215, y_3 = 0.68, y_4 = 0.0131 : 323.1 secs : initdesign
#
# [mbo] 0: source_weights=0.637,0.16,0...; lr_sig_hub=0.265; gr_hub=0.866; ltf_cutoff=0.965; damping_factor=0.499 : y_1 = 0.595, y_2 = 0.018, y_3 = 0.76, y_4 = 0.0258 : 560.3 secs : initdesign
#
# [mbo] 0: source_weights=0.302,0.0973...; lr_sig_hub=0.227; gr_hub=0.272; ltf_cutoff=0.923; damping_factor=0.601 : y_1 = 0.605, y_2 = 0.0287, y_3 = 0.75, y_4 = 0.0247 : 641.3 secs : initdesign
#
# [mbo] 0: source_weights=0.577,0.483,...; lr_sig_hub=0.95; gr_hub=0.514; ltf_cutoff=0.948; damping_factor=0.0666 : y_1 = 0.594, y_2 = 0.0233, y_3 = 0.73, y_4 = 0.024 : 502.3 secs : initdesign
#
# [mbo] 0: source_weights=0.061,0.264,...; lr_sig_hub=0.878; gr_hub=0.701; ltf_cutoff=0.977; damping_factor=0.159 : y_1 = 0.581, y_2 = 0.0212, y_3 = 0.663, y_4 = 0.0337 : 669.0 secs : initdesign
#
# [mbo] 0: source_weights=0.498,0.591,...; lr_sig_hub=0.415; gr_hub=0.742; ltf_cutoff=0.944; damping_factor=0.332 : y_1 = 0.606, y_2 = 0.0229, y_3 = 0.74, y_4 = 0.0317 : 531.8 secs : initdesign
#
# [mbo] 0: source_weights=0.235,0.76,0...; lr_sig_hub=0.65; gr_hub=0.946; ltf_cutoff=0.934; damping_factor=0.322 : y_1 = 0.594, y_2 = 0.0158, y_3 = 0.757, y_4 = 0.0297 : 598.2 secs : initdesign
#
# [mbo] 0: source_weights=0.391,0.304,...; lr_sig_hub=0.956; gr_hub=0.377; ltf_cutoff=0.926; damping_factor=0.594 : y_1 = 0.599, y_2 = 0.0271, y_3 = 0.76, y_4 = 0.0189 : 321.8 secs : initdesign
#
# [mbo] 0: source_weights=0.126,0.417,...; lr_sig_hub=0.906; gr_hub=0.383; ltf_cutoff=0.948; damping_factor=0.381 : y_1 = 0.6, y_2 = 0.0293, y_3 = 0.7, y_4 = 0.0221 : 307.9 secs : initdesign
#
# [mbo] 0: source_weights=0.147,0.989,...; lr_sig_hub=0.845; gr_hub=0.0557; ltf_cutoff=0.95; damping_factor=0.0483 : y_1 = 0.599, y_2 = 0.023, y_3 = 0.66, y_4 = 0.0141 : 484.0 secs : initdesign
#
# [mbo] 0: source_weights=0.0856,0.576...; lr_sig_hub=0.152; gr_hub=0.176; ltf_cutoff=0.969; damping_factor=0.246 : y_1 = 0.601, y_2 = 0.0271, y_3 = 0.8, y_4 = 0.0429 : 532.4 secs : initdesign
#
# [mbo] 0: source_weights=0.535,0.443,...; lr_sig_hub=0.144; gr_hub=0.809; ltf_cutoff=0.989; damping_factor=0.585 : y_1 = 0.586, y_2 = 0.0219, y_3 = 0.75, y_4 = 0.0221 : 517.2 secs : initdesign
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 1: source_weights=0.938,0.9,0....; lr_sig_hub=0.46; gr_hub=0.732; ltf_cutoff=0.936; damping_factor=0.835 : y_1 = 0.603, y_2 = 0.019, y_3 = 0.72, y_4 = 0.0189 : 551.0 secs : infill_dib
#
# [mbo] 1: source_weights=0.094,0.72,0...; lr_sig_hub=0.508; gr_hub=0.853; ltf_cutoff=0.972; damping_factor=0.975 : y_1 = 0.599, y_2 = 0.0191, y_3 = 0.69, y_4 = 0.0137 : 743.6 secs : infill_dib
#
# [mbo] 1: source_weights=0.96,0.586,0...; lr_sig_hub=0.131; gr_hub=0.0285; ltf_cutoff=0.954; damping_factor=0.0686 : y_1 = 0.605, y_2 = 0.0254, y_3 = 0.792, y_4 = 0.0359 : 523.0 secs : infill_dib
#
# [mbo] 1: source_weights=0.142,0.639,...; lr_sig_hub=0.39; gr_hub=0.899; ltf_cutoff=0.968; damping_factor=0.45 : y_1 = 0.593, y_2 = 0.0177, y_3 = 0.75, y_4 = 0.0224 : 535.2 secs : infill_dib
#
# [mbo] 1: source_weights=0.742,0.662,...; lr_sig_hub=0.685; gr_hub=0.252; ltf_cutoff=0.911; damping_factor=0.255 : y_1 = 0.608, y_2 = 0.0291, y_3 = 0.791, y_4 = 0.0429 : 540.5 secs : infill_dib
#
# [mbo] 1: source_weights=0.926,0.618,...; lr_sig_hub=0.215; gr_hub=0.897; ltf_cutoff=0.94; damping_factor=0.295 : y_1 = 0.599, y_2 = 0.0167, y_3 = 0.7, y_4 = 0.0221 : 587.0 secs : infill_dib
#
# [mbo] 1: source_weights=0.112,0.45,0...; lr_sig_hub=0.225; gr_hub=0.41; ltf_cutoff=0.962; damping_factor=0.0741 : y_1 = 0.601, y_2 = 0.0246, y_3 = 0.8, y_4 = 0.0471 : 551.3 secs : infill_dib
#
# [mbo] 1: source_weights=0.798,0.552,...; lr_sig_hub=0.41; gr_hub=0.591; ltf_cutoff=0.91; damping_factor=0.99 : y_1 = 0.608, y_2 = 0.0238, y_3 = 0.72, y_4 = 0.0177 : 559.0 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 2: source_weights=0.478,0.22,0...; lr_sig_hub=0.93; gr_hub=0.367; ltf_cutoff=0.93; damping_factor=0.206 : y_1 = 0.599, y_2 = 0.0255, y_3 = 0.78, y_4 = 0.0359 : 709.4 secs : infill_dib
#
# [mbo] 2: source_weights=0.952,0.264,...; lr_sig_hub=0.736; gr_hub=0.427; ltf_cutoff=0.934; damping_factor=0.312 : y_1 = 0.6, y_2 = 0.0268, y_3 = 0.72, y_4 = 0.0229 : 570.0 secs : infill_dib
# [mbo] 2: source_weights=0.486,0.256,...; lr_sig_hub=0.633; gr_hub=0.563; ltf_cutoff=0.99; damping_factor=0.356 : y_1 = 0.572, y_2 = 0.0303, y_3 = 0.76, y_4 = 0.0258 : 486.2 secs : infill_dib
#
# [mbo] 2: source_weights=0.958,0.648,...; lr_sig_hub=0.083; gr_hub=0.705; ltf_cutoff=0.962; damping_factor=0.284 : y_1 = 0.6, y_2 = 0.0213, y_3 = 0.76, y_4 = 0.0281 : 542.8 secs : infill_dib
#
# [mbo] 2: source_weights=0.718,0.717,...; lr_sig_hub=0.691; gr_hub=0.899; ltf_cutoff=0.973; damping_factor=0.684 : y_1 = 0.591, y_2 = 0.0209, y_3 = 0.714, y_4 = 0.0161 : 550.5 secs : infill_dib
#
# [mbo] 2: source_weights=0.5,0.271,0....; lr_sig_hub=0.518; gr_hub=0.932; ltf_cutoff=0.968; damping_factor=0.256 : y_1 = 0.595, y_2 = 0.0186, y_3 = 0.694, y_4 = 0.0213 : 483.0 secs : infill_dib
#
# [mbo] 2: source_weights=0.0808,0.412...; lr_sig_hub=0.871; gr_hub=0.883; ltf_cutoff=0.916; damping_factor=0.831 : y_1 = 0.6, y_2 = 0.0191, y_3 = 0.68, y_4 = 0.0116 : 557.2 secs : infill_dib
#
# [mbo] 2: source_weights=0.372,0.701,...; lr_sig_hub=0.275; gr_hub=0.0931; ltf_cutoff=0.923; damping_factor=0.339 : y_1 = 0.61, y_2 = 0.0314, y_3 = 0.8, y_4 = 0.0429 : 560.6 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 3: source_weights=0.674,0.188,...; lr_sig_hub=0.228; gr_hub=0.372; ltf_cutoff=0.957; damping_factor=0.373 : y_1 = 0.602, y_2 = 0.0241, y_3 = 0.76, y_4 = 0.0258 : 560.6 secs : infill_dib
#
# [mbo] 3: source_weights=0.732,0.442,...; lr_sig_hub=0.25; gr_hub=0.868; ltf_cutoff=0.944; damping_factor=0.266 : y_1 = 0.598, y_2 = 0.0141, y_3 = 0.74, y_4 = 0.0221 : 546.9 secs : infill_dib
#
# [mbo] 3: source_weights=0.774,0.593,...; lr_sig_hub=0.318; gr_hub=0.301; ltf_cutoff=0.907; damping_factor=0.987 : y_1 = 0.616, y_2 = 0.0333, y_3 = 0.75, y_4 = 0.0332 : 586.1 secs : infill_dib
#
# [mbo] 3: source_weights=0.737,0.382,...; lr_sig_hub=0.52; gr_hub=0.675; ltf_cutoff=0.917; damping_factor=0.75 : y_1 = 0.608, y_2 = 0.028, y_3 = 0.762, y_4 = 0.0266 : 542.6 secs : infill_dib
#
# [mbo] 3: source_weights=0.0648,0.824...; lr_sig_hub=0.284; gr_hub=0.653; ltf_cutoff=0.907; damping_factor=0.616 : y_1 = 0.611, y_2 = 0.0273, y_3 = 0.77, y_4 = 0.0409 : 748.4 secs : infill_dib
#
# [mbo] 3: source_weights=0.778,0.481,...; lr_sig_hub=0.217; gr_hub=0.0725; ltf_cutoff=0.984; damping_factor=0.563 : y_1 = 0.594, y_2 = 0.0302, y_3 = 0.77, y_4 = 0.0304 : 489.3 secs : infill_dib
#
# [mbo] 3: source_weights=0.107,0.548,...; lr_sig_hub=0.64; gr_hub=0.926; ltf_cutoff=0.92; damping_factor=0.275 : y_1 = 0.595, y_2 = 0.0171, y_3 = 0.74, y_4 = 0.0247 : 543.9 secs : infill_dib
#
# [mbo] 3: source_weights=0.632,0.486,...; lr_sig_hub=0.38; gr_hub=0.191; ltf_cutoff=0.975; damping_factor=0.439 : y_1 = 0.594, y_2 = 0.0289, y_3 = 0.8, y_4 = 0.0429 : 548.5 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 4: source_weights=0.212,0.0933...; lr_sig_hub=0.526; gr_hub=0.893; ltf_cutoff=0.998; damping_factor=0.859 : y_1 = 0.536, y_2 = 0.0222, y_3 = 0.7, y_4 = 0.0116 : 678.2 secs : infill_dib
#
# [mbo] 4: source_weights=0.257,0.823,...; lr_sig_hub=0.763; gr_hub=0.381; ltf_cutoff=0.988; damping_factor=0.647 : y_1 = 0.576, y_2 = 0.0314, y_3 = 0.714, y_4 = 0.0221 : 593.1 secs : infill_dib
#
# [mbo] 4: source_weights=0.919,0.682,...; lr_sig_hub=0.693; gr_hub=0.515; ltf_cutoff=0.989; damping_factor=0.701 : y_1 = 0.576, y_2 = 0.0245, y_3 = 0.755, y_4 = 0.0232 : 576.7 secs : infill_dib
#
# [mbo] 4: source_weights=0.547,0.707,...; lr_sig_hub=0.66; gr_hub=0.724; ltf_cutoff=0.943; damping_factor=0.071 : y_1 = 0.597, y_2 = 0.0218, y_3 = 0.7, y_4 = 0.0273 : 675.6 secs : infill_dib
#
# [mbo] 4: source_weights=0.448,0.898,...; lr_sig_hub=0.0334; gr_hub=0.33; ltf_cutoff=0.962; damping_factor=0.204 : y_1 = 0.607, y_2 = 0.0284, y_3 = 0.76, y_4 = 0.0429 : 645.3 secs : infill_dib
#
# [mbo] 4: source_weights=0.63,0.574,0...; lr_sig_hub=0.267; gr_hub=0.132; ltf_cutoff=0.938; damping_factor=0.243 : y_1 = 0.606, y_2 = 0.028, y_3 = 0.786, y_4 = 0.0359 : 655.3 secs : infill_dib
#
# [mbo] 4: source_weights=0.52,0.317,0...; lr_sig_hub=0.702; gr_hub=0.231; ltf_cutoff=0.915; damping_factor=0.565 : y_1 = 0.604, y_2 = 0.0298, y_3 = 0.76, y_4 = 0.0304 : 665.6 secs : infill_dib
#
# [mbo] 4: source_weights=0.721,0.38,0...; lr_sig_hub=0.137; gr_hub=0.409; ltf_cutoff=0.927; damping_factor=0.197 : y_1 = 0.61, y_2 = 0.0289, y_3 = 0.76, y_4 = 0.0359 : 703.4 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 5: source_weights=0.288,0.197,...; lr_sig_hub=0.608; gr_hub=0.513; ltf_cutoff=0.93; damping_factor=0.544 : y_1 = 0.604, y_2 = 0.0299, y_3 = 0.76, y_4 = 0.0304 : 567.7 secs : infill_dib
#
# [mbo] 5: source_weights=0.658,0.857,...; lr_sig_hub=0.499; gr_hub=0.447; ltf_cutoff=0.936; damping_factor=0.693 : y_1 = 0.612, y_2 = 0.0336, y_3 = 0.765, y_4 = 0.0359 : 510.8 secs : infill_dib
#
# [mbo] 5: source_weights=0.965,0.914,...; lr_sig_hub=0.391; gr_hub=0.474; ltf_cutoff=0.922; damping_factor=0.315 : y_1 = 0.605, y_2 = 0.026, y_3 = 0.8, y_4 = 0.0359 : 547.5 secs : infill_dib
#
# [mbo] 5: source_weights=0.493,0.39,0...; lr_sig_hub=0.262; gr_hub=0.459; ltf_cutoff=0.942; damping_factor=0.0803 : y_1 = 0.604, y_2 = 0.0272, y_3 = 0.78, y_4 = 0.0359 : 736.3 secs : infill_dib
#
# [mbo] 5: source_weights=0.758,0.224,...; lr_sig_hub=0.147; gr_hub=0.0848; ltf_cutoff=0.947; damping_factor=0.655 : y_1 = 0.613, y_2 = 0.031, y_3 = 0.8, y_4 = 0.0429 : 582.1 secs : infill_dib
#
# [mbo] 5: source_weights=0.583,0.653,...; lr_sig_hub=0.545; gr_hub=0.165; ltf_cutoff=0.941; damping_factor=0.022 : y_1 = 0.601, y_2 = 0.0251, y_3 = 0.78, y_4 = 0.0379 : 520.1 secs : infill_dib
#
# [mbo] 5: source_weights=0.0468,0.61,...; lr_sig_hub=0.153; gr_hub=0.751; ltf_cutoff=0.971; damping_factor=0.223 : y_1 = 0.594, y_2 = 0.0174, y_3 = 0.73, y_4 = 0.0221 : 481.9 secs : infill_dib
#
# [mbo] 5: source_weights=0.359,0.903,...; lr_sig_hub=0.306; gr_hub=0.305; ltf_cutoff=0.973; damping_factor=0.09 : y_1 = 0.594, y_2 = 0.0264, y_3 = 0.76, y_4 = 0.0359 : 563.0 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 6: source_weights=0.63,0.417,0...; lr_sig_hub=0.406; gr_hub=0.234; ltf_cutoff=0.916; damping_factor=0.788 : y_1 = 0.611, y_2 = 0.0312, y_3 = 0.8, y_4 = 0.0413 : 572.2 secs : infill_dib
#
# [mbo] 6: source_weights=0.422,0.376,...; lr_sig_hub=0.594; gr_hub=0.64; ltf_cutoff=0.991; damping_factor=0.595 : y_1 = 0.568, y_2 = 0.0271, y_3 = 0.74, y_4 = 0.0189 : 488.8 secs : infill_dib
#
# [mbo] 6: source_weights=0.0838,0.801...; lr_sig_hub=0.58; gr_hub=0.772; ltf_cutoff=0.906; damping_factor=0.0882 : y_1 = 0.603, y_2 = 0.021, y_3 = 0.74, y_4 = 0.0317 : 653.6 secs : infill_dib
#
# [mbo] 6: source_weights=0.193,0.808,...; lr_sig_hub=0.742; gr_hub=0.178; ltf_cutoff=0.952; damping_factor=0.422 : y_1 = 0.6, y_2 = 0.0306, y_3 = 0.77, y_4 = 0.0258 : 529.0 secs : infill_dib
#
# [mbo] 6: source_weights=0.0679,0.443...; lr_sig_hub=0.75; gr_hub=0.292; ltf_cutoff=0.943; damping_factor=0.154 : y_1 = 0.597, y_2 = 0.0277, y_3 = 0.8, y_4 = 0.0413 : 658.8 secs : infill_dib
#
# [mbo] 6: source_weights=0.126,0.734,...; lr_sig_hub=0.392; gr_hub=0.204; ltf_cutoff=0.904; damping_factor=0.13 : y_1 = 0.605, y_2 = 0.0244, y_3 = 0.8, y_4 = 0.0359 : 630.5 secs : infill_dib
#
# [mbo] 6: source_weights=0.71,0.338,0...; lr_sig_hub=0.0682; gr_hub=0.692; ltf_cutoff=0.987; damping_factor=0.402 : y_1 = 0.589, y_2 = 0.0192, y_3 = 0.717, y_4 = 0.0198 : 475.6 secs : infill_dib
#
# [mbo] 6: source_weights=0.175,0.171,...; lr_sig_hub=0.874; gr_hub=0.529; ltf_cutoff=0.965; damping_factor=0.732 : y_1 = 0.598, y_2 = 0.0303, y_3 = 0.73, y_4 = 0.0235 : 487.0 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 7: source_weights=0.232,0.955,...; lr_sig_hub=0.249; gr_hub=0.742; ltf_cutoff=0.955; damping_factor=0.806 : y_1 = 0.606, y_2 = 0.0176, y_3 = 0.74, y_4 = 0.0189 : 556.2 secs : infill_dib
#
# [mbo] 7: source_weights=0.277,0.422,...; lr_sig_hub=0.205; gr_hub=0.786; ltf_cutoff=0.948; damping_factor=0.784 : y_1 = 0.604, y_2 = 0.0164, y_3 = 0.69, y_4 = 0.0214 : 556.4 secs : infill_dib
#
# [mbo] 7: source_weights=0.37,0.866,0...; lr_sig_hub=0.405; gr_hub=0.485; ltf_cutoff=0.942; damping_factor=0.81 : y_1 = 0.603, y_2 = 0.0277, y_3 = 0.714, y_4 = 0.0221 : 564.6 secs : infill_dib
# [mbo] 7: source_weights=0.537,0.253,...; lr_sig_hub=0.061; gr_hub=0.657; ltf_cutoff=0.958; damping_factor=0.28 : y_1 = 0.599, y_2 = 0.0168, y_3 = 0.76, y_4 = 0.0221 : 546.6 secs : infill_dib
#
# [mbo] 7: source_weights=0.338,0.0879...; lr_sig_hub=0.365; gr_hub=0.384; ltf_cutoff=0.964; damping_factor=0.677 : y_1 = 0.602, y_2 = 0.0302, y_3 = 0.76, y_4 = 0.0304 : 565.4 secs : infill_dib
#
# [mbo] 7: source_weights=0.576,0.706,...; lr_sig_hub=0.468; gr_hub=0.942; ltf_cutoff=0.921; damping_factor=0.301 : y_1 = 0.598, y_2 = 0.0153, y_3 = 0.71, y_4 = 0.0221 : 524.5 secs : infill_dib
#
# [mbo] 7: source_weights=0.896,0.679,...; lr_sig_hub=0.541; gr_hub=0.214; ltf_cutoff=0.91; damping_factor=0.537 : y_1 = 0.604, y_2 = 0.0298, y_3 = 0.82, y_4 = 0.0359 : 746.7 secs : infill_dib
#
# [mbo] 7: source_weights=0.721,0.18,0...; lr_sig_hub=0.646; gr_hub=0.0903; ltf_cutoff=0.948; damping_factor=0.871 : y_1 = 0.61, y_2 = 0.033, y_3 = 0.755, y_4 = 0.0304 : 512.7 secs : infill_dib
#
# Mapping in parallel: mode = multicore; level = mlrMBO.feval; cpus = 8; elements = 8.
#
# [mbo] 8: source_weights=0.568,0.852,...; lr_sig_hub=0.497; gr_hub=0.643; ltf_cutoff=0.961; damping_factor=0.236 : y_1 = 0.597, y_2 = 0.0229, y_3 = 0.75, y_4 = 0.0429 : 544.8 secs : infill_dib
#
# [mbo] 8: source_weights=0.599,0.33,0...; lr_sig_hub=0.488; gr_hub=0.354; ltf_cutoff=0.945; damping_factor=0.163 : y_1 = 0.602, y_2 = 0.0273, y_3 = 0.786, y_4 = 0.0359 : 548.6 secs : infill_dib
#
# [mbo] 8: source_weights=0.623,0.121,...; lr_sig_hub=0.971; gr_hub=0.885; ltf_cutoff=0.989; damping_factor=0.751 : y_1 = 0.563, y_2 = 0.0196, y_3 = 0.68, y_4 = 0.0106 : 528.0 secs : infill_dib
#
# [mbo] 8: source_weights=0.0807,0.739...; lr_sig_hub=0.506; gr_hub=0.642; ltf_cutoff=0.912; damping_factor=0.319 : y_1 = 0.607, y_2 = 0.0258, y_3 = 0.726, y_4 = 0.0397 : 563.9 secs : infill_dib
#
# [mbo] 8: source_weights=0.597,0.543,...; lr_sig_hub=0.613; gr_hub=0.38; ltf_cutoff=0.924; damping_factor=0.133 : y_1 = 0.601, y_2 = 0.0235, y_3 = 0.78, y_4 = 0.0304 : 562.8 secs : infill_dib
#
# [mbo] 8: source_weights=0.97,0.123,0...; lr_sig_hub=0.225; gr_hub=0.694; ltf_cutoff=0.942; damping_factor=0.597 : y_1 = 0.605, y_2 = 0.021, y_3 = 0.74, y_4 = 0.0284 : 524.1 secs : infill_dib
#
# [mbo] 8: source_weights=0.573,0.0879...; lr_sig_hub=0.189; gr_hub=0.257; ltf_cutoff=0.909; damping_factor=0.617 : y_1 = 0.607, y_2 = 0.0265, y_3 = 0.76, y_4 = 0.0304 : 526.9 secs : infill_dib
#
# [mbo] 8: source_weights=0.63,0.346,0...; lr_sig_hub=0.94; gr_hub=0.507; ltf_cutoff=0.96; damping_factor=0.36 : y_1 = 0.591, y_2 = 0.0237, y_3 = 0.661, y_4 = 0.0161 : 733.4 secs : infill_dib
#
# Stopped parallelization. All cleaned up.
