# %% [markdown]
# # Part 4

# %% [markdown]
# - **INPUT:**
#     -  ```counts_norm.mtx```
#     -  ```anno_cells_norm.txt```
#     -  ```anno_samples_norm.txt```
#     -  ```anno_genes_norm.txt```
#     -  ```cell_relabelling.csv``` file containing unified cell type annotations. Stored in additional_input_files sub-directory.
#
#
# - **OUTPUT:**
#
#     -  ```counts_corr.csv.gz```
#     -  ```anno_cells_corr.txt```
#     -  ```anno_samples_corr.txt```
#     -  ```anno_genes_corr.txt```
#     -  ```adata_afterCorrection.h5ad```

# %% [markdown]
# ### load data

# %%
import numpy as np
import scanpy as sc
import pandas as pd
import os
import shutil

# %%
adata=sc.read_csv("../../../results/data_preprocessing/Lasry/filtered/lasry_batch_corr.csv.gz")

# %%
adata_beforeCorrection = adata.T

# %%
# read in cell annotation file
anno_cells = pd.read_csv("../../../results/data_preprocessing/Lasry/filtered/anno_cells_batch_corr.txt", sep = "\t")
# Out:
# /tmp/ipykernel_19662/1854930244.py:2: DtypeWarning: Columns (22,26,27,28,29,30,32,33,34,35,36,37,38,41,42,43,44,47,48,50,55,57,58,61,65,67,68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   anno_cells = pd.read_csv("../../../results/data_preprocessing/Lasry/filtered/anno_cells_batch_corr.txt", sep = "\t")

# %%
# read in sample annotation file
anno_samples = pd.read_csv("../../../results/data_preprocessing/Lasry/filtered/anno_samples_batch_corr.txt", sep = "\t")

# %%
# read in gene annotation file
anno_genes = pd.read_csv("../../../results/data_preprocessing/Lasry/filtered/anno_genes_batch_corr.txt", sep = "\t")

# %%
# load cell subtype and color keys
cell_relabel=pd.read_csv("../../../data/cell_relabelling.csv"
                        ,sep=';')

# %% [markdown]
# ### process data

# %%
adata_beforeCorrection.var_names=anno_genes['gene_symbol']
print("adata_beforeCorrection.var_names[1:10]")
print(adata_beforeCorrection.var_names[1:10])
adata_beforeCorrection.var = anno_genes
adata_beforeCorrection.var.index = adata_beforeCorrection.var.index.astype(str)
# Out:
# adata_beforeCorrection.var_names[1:10]
# Index(['LINC01409', 'LINC01128', 'LINC00115', 'FAM41C', 'AL645608.2', 'NOC2L',
#        'KLHL17', 'PLEKHN1', 'HES4'],
#       dtype='object', name='gene_symbol')

# %%
adata_beforeCorrection.obs_names=anno_cells['cell_ID']
print("adata_beforeCorrection.obs_names[1:10]")
print(adata_beforeCorrection.obs_names[1:10])
adata_beforeCorrection.obs = anno_cells
adata_beforeCorrection.obs.index = adata_beforeCorrection.obs.index.astype(str)
# Out:
# adata_beforeCorrection.obs_names[1:10]
# Index(['2020.09.15.AML0024.CATCAAGTCCGAGAAG',
#        '2020.09.15.AML0024.CATCCACAGGGACCAT',
#        '2020.09.15.AML0024.CCTCAACAGAGCAAGA',
#        '2020.09.15.AML0024.CCTCAACAGTTCCATG',
#        '2020.09.15.AML0024.CCTCAACGTAGAATAC',
#        '2020.09.15.AML0024.CCTCAACGTTCTCCCA',
#        '2020.09.15.AML0024.CCTCAACTCCGAACGC',
#        '2020.09.15.AML0024.CCTCAACTCTAGTCAG',
#        '2020.09.15.AML0024.CCTCACAAGACAGTCG'],
#       dtype='object', name='cell_ID')

# %% [markdown]
# ### prepare for the visualization

# %%
# define colors
colors_cell_type=dict(zip(cell_relabel["cell_type"],cell_relabel["cell_type_color_hex"]))
print(colors_cell_type)
# Out:
# {'B': '#4FC384', 'Mono': '#F09040', 'T': '#4F92EE', 'DC': '#854701', 'Ery': '#F72E3A', 'Megakaryocytes': '#C89B7A', 'NK': '#4F64EE', 'HSPC': '#D040F0', 'Gran': '#CD6600', 'PeriVasc': '#BEBEBE', 'LymP': '#556B2F'}

# %%
#there is an error at line 9, cell_subtype is only 2 values?
adata_beforeCorrection.obs["cell_subtype"].value_counts()
# Out:
# cell_subtype
# Mono      18004
# CD8_T      6272
# CD4_T      4989
# B          4413
# HSPC       3169
# NK         3078
# Gran       2332
# Ery        1674
# cDC        1092
# pDC         542
# gd_T        487
# Plasma      352
# MAIT        298
# Name: count, dtype: int64

# %%
# rename "malignangt" columns into "bares_mutatoin"
adata_beforeCorrection.obs["bares_mutation"] = adata_beforeCorrection.obs["malignant"].astype('str')

# %%
# define color schemes
colors_cell_subtype=dict(zip(cell_relabel["cell_subtype"],cell_relabel["cell_subtype_color_hex"]))
print(colors_cell_subtype)

colors_cell_type=dict(zip(cell_relabel["cell_type"],cell_relabel["cell_type_color_hex"]))
print(colors_cell_type)
# Out:
# {'B': '#4FC384', 'Mono': '#F09040', 'pro_Mono': '#F0AD40', 'CD4_T': '#4FCCEE', 'CD8_T': '#4F92EE', 'pDC': '#854701', 'cDC': '#B95D10', 'early_Ery': '#F72E3A', 'late_Ery': '#C72D37', 'Megakaryocytes': '#C89B7A', 'NK': '#4F64EE', 'Plasma': '#317E54', 'HSPC': '#D040F0', 'MAIT': '#00688B', 'Gran': '#CD6600', 'gd_T': '#00BFFF', 'PeriVasc': '#BEBEBE', 'LymP': '#556B2F', 'Ery': '#C72D37'}
# {'B': '#4FC384', 'Mono': '#F09040', 'T': '#4F92EE', 'DC': '#854701', 'Ery': '#F72E3A', 'Megakaryocytes': '#C89B7A', 'NK': '#4F64EE', 'HSPC': '#D040F0', 'Gran': '#CD6600', 'PeriVasc': '#BEBEBE', 'LymP': '#556B2F'}

# %%
adata_beforeCorrection.uns["health_status_colors"] = ["#7C001F" # bordeau for AML
                                                     , "#7ac5cd" # CadetBlue3 for healthy
                                                     ]

adata_beforeCorrection.uns["bares_mutation_colors"] = ["#A6ACAF" # grey for FALSE
                                                  , "#C0392B" # red for TRUE
                                                 ]

# %% [markdown]
# ### visualize before batch correction

# %%
# logtransform before HVG calculation
sc.pp.log1p(adata_beforeCorrection)

sc.pp.highly_variable_genes(adata_beforeCorrection)
sc.pl.highly_variable_genes(adata_beforeCorrection)
# Out:
# /home/mami/.local/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:207: RuntimeWarning: invalid value encountered in log
#   dispersion = np.log(dispersion)

# %%
# print how many HVGs we have:
print("Nr of HVGs:")
print(sum(adata_beforeCorrection.var.highly_variable))
# Out:
# Nr of HVGs:
# 3106

# %%
sc.tl.pca(adata_beforeCorrection, svd_solver='arpack')

# %%
sc.pl.pca(adata_beforeCorrection
          , color=["cell_type"]
          ,palette=colors_cell_type
          ,save="_beforeCorrection_cell_type.pdf"
         )
# Out:
# WARNING: saving figure to file figures/pca_beforeCorrection_cell_type.pdf
# /home/mami/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pp.neighbors(adata_beforeCorrection)
# Out:
# /home/mami/.local/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/mami/.local/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/mami/.local/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/mami/.local/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/mami/.local/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
sc.tl.umap(adata_beforeCorrection)

# %%
sc.pl.umap(adata_beforeCorrection
           , color=["cell_type"]
           ,palette=colors_cell_type
           ,save="_beforeCorrection_cell_type.pdf"
          )
# Out:
# WARNING: saving figure to file figures/umap_beforeCorrection_cell_type.pdf
# /home/mami/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_beforeCorrection
           , color=["cell_subtype"]
          ,palette=colors_cell_subtype
          ,save="_beforeCorrection_cell_subtype.pdf"
          )
# Out:
# WARNING: saving figure to file figures/umap_beforeCorrection_cell_subtype.pdf
# /home/mami/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_beforeCorrection
           , color=["sample_ID"]
          ,save="_beforeCorrection_sample_ID.pdf"
          )
# Out:
# WARNING: saving figure to file figures/umap_beforeCorrection_sample_ID.pdf
# /home/mami/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_beforeCorrection
           , color=["health_status"]
          ,save="_beforeCorrection_health_status.pdf"
          )
# Out:
# WARNING: saving figure to file figures/umap_beforeCorrection_health_status.pdf
# /home/mami/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_beforeCorrection
           , color=["bares_mutation"]
          ,save="_beforeCorrection_malignant.pdf"
          )
# Out:
# WARNING: saving figure to file figures/umap_beforeCorrection_malignant.pdf
# /home/mami/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_beforeCorrection
           , color=["cell_type_original"]
           #,legend_loc='center'
          ,save="_beforeCorrection_cell_type_original.pdf"
          )
# Out:
# WARNING: saving figure to file figures/umap_beforeCorrection_cell_type_original.pdf
# /home/mami/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Export

# %%
output_path = os.getcwd()
output_path = output_path.replace("src","results")
output_path = output_path + "/normalized/"

# %%
output_path
# Out:
# '/home/mami/Maria/polish/clean/community-paper/results/data_preprocessing/Lasry/normalized/'

# %%
# for file_name in os.listdir("figures/"):
#     shutil.move(os.path.join("figures/", file_name), output_path)
# shutil.rmtree("figures/")

# %%
# export counts as csv.gz
print("save counts_corr.csv.gz")

counts_corr=adata_beforeCorrection.to_df().transpose()
counts_corr.index = adata_beforeCorrection.var.gene_symbol
counts_corr.columns = adata_beforeCorrection.obs.cell
counts_corr.to_csv(output_path + "counts_corr.csv.gz"
                   ,index=True
                   ,compression="gzip"
                   )
# Out:
# save counts_corr.csv.gz

# %%
# export anno_cells_corr
print("save anno_cells_corr.txt")
adata_beforeCorrection.obs.to_csv(output_path + "anno_cells_corr.txt"
                    ,sep = "\t"
                    ,index = True)
# Out:
# save anno_cells_corr.txt

# %%
# export anno_samples_corr
print("save anno_samples_corr.txt")
anno_samples.to_csv(output_path + "anno_samples_corr.txt"
                    ,sep = "\t"
                    ,index = True)
# Out:
# save anno_samples_corr.txt

# %%
# export anno_genes_corr
print("save anno_genes_corr.txt")
adata_beforeCorrection.var.to_csv(output_path + "anno_genes_corr.txt"
                    ,sep = "\t"
                    ,index = True)
# Out:
# save anno_genes_corr.txt

# %%
output_path
# Out:
# '/work/project/ladcol_011/polish/community-paper/results/data_preprocessing/Lasry/normalized/'
